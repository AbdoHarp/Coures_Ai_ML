# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("D:/data/diabetes.csv")
df.head()
# print(df.shape)
# print(df.info)
# print(df.isnull().any())

fig ,axs = plt.subplots(9,1, dpi=95, figsize=(7,17))
i=0
for col in df.columns:
    axs[i].boxplot(df[col],vert= False)
    axs[i].set_ylabel(col)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
plt.figure(dpi=130)
sns.heatmap(df.corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("D:/data/diabetes.csv")

plt.figure(dpi=130)
sns.heatmap(df.corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >

# %%
plt.pie(df.Outcome.value_counts(),
        labels= ["Diabetes", "Not Diabates"],
        autopct= "%.f", shadow= True)
plt.title("outcom proportionality")
# Out:
# Text(0.5, 1.0, 'outcom proportionality')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
test = pd.read_csv("D:/data/test.csv")
test.head()
test.info
test.isnull().any
test.isnull().sum()
test.describe
train =pd.read_csv("D:/data/train.csv")
train.head()
train.info
train.isnull().any
train.isnull().sum()
train.describe

plt.show()

# %% [raw]
# test = pd.read_csv("D:/data/test.csv")
# test.head()
# test.info
# test.isnull().any
# test.isnull().sum()
# test.describe
# train =pd.read_csv("D:/data/train.csv")
# train.head()
# train.info
# train.isnull().any
# train.isnull().sum()
# train.describe

# %%
test = pd.read_csv("D:/data/test.csv")
test.head()
test.info
test.isnull().any
test.isnull().sum()
test.describe
train =pd.read_csv("D:/data/train.csv")
train.head()
train.info
train.isnull().any
train.isnull().sum()
train.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# from sklearn.model_selection import ModelSelection
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import suspect as sus
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# from sklearn.metrics import r2_score


df=pd.read_csv("D:/Data/Salary_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
data = pd.read_csv("D:/Data/data (1).csv")
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression

# data = pd.read_csv("D:/Data/data (1).csv")
# # data.info()
# # data.isnull().any()
# y= data.Price
# # y.head()
# data.drop(columns=["Price", "Address"], inplace=True)
# x=data.copy()
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
# # use model
# lr_model = LinearRegression()
# # fit model
# lr_model.fit(x_train,y_train)
# y_pred = lr_model.predict(x_test)
# data.iloc[5].values
# print(lr_model.predict([[8.01757542e+04, 4.98840776e+00, 6.10451244e+00, 4.04000000e+00,
#     2.67484284e+04]]))
# y[5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 23
#      17 y_pred = lr_model.predict(x_test)
#      18 # data.iloc[5].values
#      19 # print(lr_model.predict([[8.01757542e+04, 4.98840776e+00, 6.10451244e+00, 4.04000000e+00,
#      20 #     2.67484284e+04]]))
#      21 # y[5]
# ---> 23 mse = metrics.mean_absolute_error(y_test, y_pred)
#      24 mse
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# # **Evaluation**:
#
# # 1 Mean absolute error ----> MAE
# # 2 Mean squared error ----> MSE
# # 3 Root mean squared error ----> RMSE
# # 4 R2 squared
# -----> little value ----> MAE, MSE, RMSE
# ----->Big value ----> R_squared -----> better form 40-80% or above

# %%
salary = pd.read_csv("D:/Data/Salary_Data.csv")
salary.head()
# salary.info()
# salary.isnull().any()

# y = salary.Salary
# salary.drop(columns=['Salary'],inplace=True)
# x = salary.copy()

# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# lr_model = LinearRegression()
# lr_model.fit(x_train,y_train)
# y_pred = lr_model.predict(x_test)
# salary.iloc[5].values
# print(lr_model.predict([[2.9]]))
# y[5]
# from sklearn.metrics import r2_score
# from sklearn import metrics
# 1-metrics.r2_score(y_test,y_pred)
# metrics.r2_score(y_test,y_pred)


# mse= metrics.mean_squared_error(y_test,y_pred)
# mse
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes
# [52654.07406712]
# c:\Users\Soft\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 0.9347210011126782

# %%
c = [i for i in range(1,len(y_test)+1,1)]
plt.plot(c,y_test,color='red',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')

plt.xlabel("index")
plt.ylabel("Salary")
plt.title("prediction vs. actual salary")
plt.show()
